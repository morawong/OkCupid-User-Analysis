# %% [markdown]
# # OkCupid Marketing Project

# %% [markdown]
# ## <a name="bg">0. Background</a>

# %% [markdown]
# ### <a name="intro">Introduction to OkCupid</a>
#
# Online dating is a multi-billion dollar industry. The OkCupid userbase consists of more than 3.5 million active users. In aggregate, OkCupid's userbase has the most diverse demographics and data-rich profiles.
#
# The marketing department at OkCupid would like to better understand its customers and potential customers. This will help the company to:
# * measure user engagement (and engagements ;) )
# * create a baseline against which to evaluate the effectiveness of new marketing campaigns
# * make recommendations for new products or features
#
# You been engaged as a data analyst at OkCupid and assigned to investigate a sample of users collected in San Francisco to identify business development opportunities. This assignment includes pulling the data together using SQL, completing an exploratory data analysis in Python, and producing a report about your findings.
#
#
# ### Email from your boss
#
# > Hi!
#
# > We’re expanding targeted ads for companies in San Francisco. The Chief Marketing Officer needs to present on Monday!! I need you to make this your top priority this week.
#
# > We’re on a really tight deadline for this project, so there are two key milestones:
# > * Wednesday at 6pm: Send me your SQL code and Python EDA in a Jupyter notebook.
# > * Thursday at 6pm: Send me your complete report.
#
# > Few other things:
# > * We’re only interested in data from 2016-2017.
# > * It looks like there are more men than women in San Francisco - that doesn't sound right. Can you take a deeper look into that?
#
# > Best,
#
# > Rachel Turner
#
# > Senior Data Analyst, OKCupid
#
#
# ### Communication with your boss
#
# Your boss, Rachel, is here to help you. You haven't known Rachel very long, but you can reach out to her for clarification so you can continue making progress. You can reach out to Rachel via slack (@rachel) to ask questions.
#
# Check-in with Rachel at the beginning (9am) and end of your day (3pm) to let her know how things are going. She's the type of boss that likes to stay informed about things and will look to you for proactive upwards communication about how the analysis is coming along. Best practices for business communication apply, even on Slack!
#
# Rachel is happy to help you throughout the project but insists that you follow a specific protocol when reaching out for help. Be sure to have three pieces of information ready: 1) a screen capture of your code including the broken line of code and the last line of the error message, 2) a description of what your code should be doing, 3) a summary of or link to at least one solution from StackOverflow that you tried to use. ** Rachel will respond to any requests that don't include this information with a reminder to follow the protocol in order to get her help. **
#
# ### Deliverables
#
# This Python notebook is designed to walk you through the steps of an end-to-end data analysis project. This can be completed within the Jupyter notebook itself with the accompanying SQLite database file. Note, the okcupid_sqlite.db file must be in the same folder as this notebook in order for you to use it within Jupyter.</a>.
#
# **By Wednesday at midnight**, please submit your Jupyter notebook linked in the Google Calendar event located [here](https://calendar.google.com/event?action=TEMPLATE&tmeid=OXZzYjJ0ZDFoajc4M2QwdWIwazBucWhyMTggbWlzc2lvbnUuY29tX2NmNHBmcWhvYjhzbWpmMWpqdWozanFldGQ4QGc&tmsrc=missionu.com_cf4pfqhob8smjf1jjuj3jqetd8%40group.calendar.google.com).</font>
#
# **By Friday at 9am**, please submit your final report in Google Slides to the link in the Google Calendar event located [here](https://calendar.google.com/event?action=TEMPLATE&tmeid=dGIwYmZub2pxbXFmYTY2dXA5OXRwNmxmazAgbWlzc2lvbnUuY29tX2NmNHBmcWhvYjhzbWpmMWpqdWozanFldGQ4QGc&tmsrc=missionu.com_cf4pfqhob8smjf1jjuj3jqetd8%40group.calendar.google.com).
#
# ### Rubric (Grading)
#
# The project will be assessed out of **100 points.**
#
# * Documented code and questions are answered **10%**
#     - Thorough use of comments to explain any code
#     - Bolded questions in the markdown cells have been answered
#
#
# * Reproducible SQL / Python code **30%**
#     - The code works
#     - Proper use of joins in SQL to consolidate data into one table
#     - Use of Pandas for data manipulation
#     - Use of Seaborn, Matplotlib to render visualizations
#
#
# * Polished Report **30%**
#     - Visualization choices consistent with data and conclusions.
#     - Titles, legends, axes labels included
#     - Clear, succinct communication of insights
#     - Polished slides that utilize data visualization best practices
#
#
# * Professionalism **10%**
#     - Check-ins with Rachel on slack are timely (9am, 3pm for daily check-ins).
#     - Questions are well-researched
#     - Courteous communication
#
#
# * Timeliness **20%**
#     - Deadlines are met unless proactively and professionally communicated to Rachel.

# %% [markdown]
# ## <a name="define">1. Define the Project.</a>
#
# *Talk to your colleagues and reach out to Rachel if you have any clarifying questions!*
#
# ** Question 1. What is the business question that we need to answer? **
#
# *The marketing team is in need of a way of measuring the effect that their marketing campaigns are having on their user base. By understanding what is effective in terms of the variables being tracked the marketing team will have access to information that will inform the delivery of their product offerings and features.*
#
# ** Question 2. What are the dependent variables of interest? How do these directly relate to business metrics? **
#
# *Height, status, smoker, other, education, drugs, drinks, diet, career, bodytype.
#
# ** Question 3. What are the independent variables which might influence those dependent variables? **
#
# *Demographic,ethnicity, orientation, sex, location, age.*
#
# ** Question 4. State three scientific hypotheses that you might test. **
#
# *1. Income level will be on the higher end in our average user *
#
# *2. Average age will be in the under 40 range *
#
# *3. There will be more males on average*

# %% [markdown]
# ## <a name="wrangle">2. Wrangle the data.</a>
#
# It's time to dive into the data!
#
# The OkCupid data have been stored in different tables to conform to the forms of normalization (hint: can read up about normlization <a href="https://www.essentialsql.com/get-ready-to-learn-sql-database-normalization-explained-in-simple-english/">here</a> if you want to get ahead for next module). *Note:* You do not need to understand normalization to complete this project.
#
# As you get into the data, you'll notice there are a number of foreign keys which link out to other tables. Your objective is to write SQL to create a single resulting that replaces the foreign keys with their corresponding values. You will also need to pull in any additional information from other tables by matching on the IDs.
#
# When it comes to our analysis, it will be easier if we can pull all of the information from the different tables into one single dataframe to be used for our analysis. You are equipped with the SQL skills you need to complete the task.
#
# **Your final SQL statement in the cell below should translate into a single Python DataFrame containing the data from all of the tables JOINED into a single table**. From that pandas DataFrame, you'll complete your exploratory data analysis and visualizations in your report. You must complete the SQL portion of the analysis BEFORE moving on to your EDA report.
#
# **Tips:**
# * *Optional/Stretch* You may find it helpful to create a relationship diagram of the various tables in the database to understand how they connect together. Although not required, a relationship diagram can help you think plan out your SQL query. in order to write the SQL to generate the single Python DataFrame.  [Here](https://www.jooq.org/img/sakila.png) is a link to the relationship diagram from a recent SQL assessment. [LucidChart](http://www.lucidchart/) is a great tool for creating these digrams.
# * Add your relationship diagram to your Google Slides report for full credit for the optional exercise.
# * Focus on mapping the primary and foreign keys instead of worring about every attribute in every table. In other words, focus on how the tables are connected.
#
# Sample SQL code featuring the demographics table has been included below. You can explore the data with SQL statements embedded in Pandas ([here](https://www.dataquest.io/blog/python-pandas-databases). You can also explore the tables using a database browser like [this](http://sqlitebrowser.org/) one.
#
# As you'll see in the code block below, the Pandas statements you need to read the SQLite database are given to you to help get things moving (the statements assume your database file is stored in the same file directory as your Jupyter notebook). You'll need to replace the simple statement below with your own SQL code.
#
# ### Exercise 2.
#
# ** Use SQL to combine the tables into a single table and translate that table into a single DataFrame named df. **.
#
# *The tables in the okcupid_sqlite.db include: *
#
# * height
# * status
# * smoker
# * orientation
# * other
# * education
# * drugs
# * drinks
# * diet
# * career
# * bodytype
# * demographic
#
# **(START BY RUNNING THE CELL BELOW)**

# %%
# These three statements will import all the necessary packages
# and functions to work with our Sqlite database. 
# You can learn more about the features of
# each of these libraries by googling 'Python <package_name> library' 

import sqlite3
import pandas as pd

# This statement will allow us to connect our Jupyter Notebook to our database.
# The sqlite3 connect function expects the name of our database file as a 
# string as an input.

database = "okcupid_sqlite.db"
connection = sqlite3.connect(database)

# You will only need to the modify the SQL string below to
# produce the result requested in the description above. Get started by 
# running this cell to see how this code works and the resulting contents
# of the demographic table.

# REPLACE SELECT SQL STRING WITH YOUR QUERY.
df_demographic = pd.read_sql_query("""
        SELECT d.id, d.age, bt.body_type, sta.status, smk.smokes, o.orientation, drg.drugs, dri.drinks, di.diet, c.job, c.income, d.sex, d.offspring
        FROM demographic d
        LEFT JOIN bodytype bt ON d.body_type= bt.btid
        LEFT JOIN status sta ON d.status = sta.STSID
        LEFT JOIN smoker smk ON d.smokes = smk.SID
        LEFT JOIN orientation o ON d.orientation = o.ORID
        LEFT JOIN drugs drg ON d.drugs = drg.DRGID
        LEFT JOIN drinks dri ON d.drinks = dri.DRID
        LEFT JOIN diet di ON d.diet = di.DID 
        LEFT JOIN career c ON d.id = c.id
        LEFT JOIN other oth ON d.id = oth.id
        LEFT JOIN education e ON d.id = e.id
        LEFT JOIN height h ON d.id = h.id
        WHERE d.last_online > 2016
        
    """, connection)

# PRINT OUT THE DATAFRAME TO SEE THE RESULTS OF YOUR QUERY.

df_demographic
# Out:
#           id  age       body_type          status          smokes orientation  \
# 0          1   22  a little extra          single       sometimes    straight
# 1          2   35         average          single              no    straight
# 2          3   38            thin       available              no    straight
# 3          4   23            thin          single              no    straight
# 4          5   29        athletic          single              no    straight
# 5          6   29         average          single              no    straight
# 6          7   32             fit          single            None    straight
# 7          8   31         average          single              no    straight
# 8          9   24            None          single   when drinking    straight
# 9         10   37        athletic          single              no    straight
# 10        11   35         average       available             yes    straight
# 11        12   28         average  seeing someone              no    straight
# 12        13   24            None          single            None    straight
# 13        14   30          skinny          single              no    straight
# 14        15   29            thin          single              no    straight
# 15        16   39             fit          single              no    straight
# 16        17   33             fit          single       sometimes    straight
# 17        18   26         average          single              no    straight
# 18        19   31         average          single              no    straight
# 19        20   33        athletic          single              no    straight
# 20        21   27         average          single              no    straight
# 21        22   22        athletic          single              no    straight
# 22        23   30             fit          single              no    straight
# 23        24   30            thin          single              no    straight
# 24        25   33            thin          single       sometimes    straight
# 25        26   28             fit          single              no    straight
# 26        27   22             fit          single  trying to quit    straight
# 27        28   22         average          single              no    straight
# 28        29   30             fit          single              no    straight
# 29        30   32             fit          single              no    straight
# ...      ...  ...             ...             ...             ...         ...
# 59913  60523   29             fit          single              no    straight
# 59914  60524   26             fit          single              no    straight
# 59915  60525   27    full figured  seeing someone             yes         gay
# 59916  60526   40        athletic          single            None    straight
# 59917  60527   22            None          single              no    straight
# 59918  60528   33             fit          single            None    straight
# 59919  60529   22            thin          single              no    straight
# 59920  60530   22      overweight          single       sometimes    straight
# 59921  60531   25            None          single              no    straight
# 59922  60532   28         average          single              no    straight
# 59923  60533   28        athletic          single              no    straight
# 59924  60534   26    full figured          single              no    straight
# 59925  60535   29         average          single   when drinking    straight
# 59926  60536   27         average          single              no    straight
# 59927  60537   41           curvy          single              no         gay
# 59928  60538   24             fit          single              no    straight
# 59929  60539   21         average          single             yes    straight
# 59930  60540   30            None          single            None    straight
# 59931  60541   43         average          single              no    straight
# 59932  60542   33           curvy          single   when drinking    straight
# 59933  60543   25         average          single              no    straight
# 59934  60544   32            thin          single              no    bisexual
# 59935  60545   48         average          single            None    straight
# 59936  60546   52            None          single              no    straight
# 59937  60547   31            None          single              no    straight
# 59938  60548   59            None          single              no    straight
# 59939  60549   24             fit          single              no    straight
# 59940  60550   42         average          single              no    straight
# 59941  60551   27        athletic          single  trying to quit    straight
# 59942  60552   39         average          single       sometimes         gay
#
#            drugs      drinks                 diet  \
# 0          never    socially    strictly anything
# 1      sometimes       often         mostly other
# 2           None    socially             anything
# 3           None    socially           vegetarian
# 4          never    socially                 None
# 5           None    socially      mostly anything
# 6          never    socially    strictly anything
# 7          never    socially      mostly anything
# 8           None    socially    strictly anything
# 9          never  not at all      mostly anything
# 10          None    socially      mostly anything
# 11         never    socially      mostly anything
# 12          None       often                 None
# 13         never    socially      mostly anything
# 14         never    socially      mostly anything
# 15          None    socially    strictly anything
# 16          None    socially                 None
# 17         never    socially                 None
# 18         never      rarely    mostly vegetarian
# 19         never    socially      mostly anything
# 20         never    socially      mostly anything
# 21         never    socially                 None
# 22         never    socially      mostly anything
# 23         never  not at all       strictly vegan
# 24     sometimes    socially    strictly anything
# 25         never      rarely             anything
# 26         never    socially      mostly anything
# 27         never    socially             anything
# 28          None    socially                 None
# 29     sometimes    socially                 None
# ...          ...         ...                  ...
# 59913       None    socially                 None
# 59914      never    socially      mostly anything
# 59915  sometimes    socially    mostly vegetarian
# 59916       None        None                 None
# 59917  sometimes    socially      mostly anything
# 59918      never    socially                 None
# 59919  sometimes    socially           vegetarian
# 59920      never    socially    strictly anything
# 59921      never    socially                 None
# 59922      never    socially      mostly anything
# 59923      never    socially      mostly anything
# 59924       None    socially                 None
# 59925      never    socially      mostly anything
# 59926  sometimes    socially  strictly vegetarian
# 59927      never    socially             anything
# 59928      never      rarely  strictly vegetarian
# 59929  sometimes    socially                 None
# 59930      never    socially                 None
# 59931       None    socially             anything
# 59932      never    socially             anything
# 59933      never    socially      mostly anything
# 59934       None    socially             anything
# 59935       None        None                 None
# 59936      never    socially                 None
# 59937      never    socially                 None
# 59938      never    socially                 None
# 59939  sometimes       often      mostly anything
# 59940      never  not at all      mostly anything
# 59941      often    socially      mostly anything
# 59942       None    socially                 None
#
#                                      job  income sex  \
# 0                         transportation      -1   m
# 1                   hospitality / travel   80000   m
# 2                                   None      -1   m
# 3                                student   20000   m
# 4            artistic / musical / writer      -1   m
# 5         computer / hardware / software      -1   m
# 6                                   None      -1   f
# 7            artistic / musical / writer      -1   f
# 8                                   None      -1   f
# 9                                student      -1   m
# 10                                  None      -1   m
# 11     banking / financial / real estate   40000   m
# 12                 entertainment / media      -1   m
# 13           sales / marketing / biz dev   30000   f
# 14                                 other   50000   f
# 15                     medicine / health      -1   f
# 16                 entertainment / media      -1   m
# 17     banking / financial / real estate      -1   f
# 18                     medicine / health      -1   m
# 19          science / tech / engineering      -1   m
# 20           sales / marketing / biz dev      -1   f
# 21                               student      -1   f
# 22                executive / management      -1   m
# 23                  education / academia      -1   m
# 24           artistic / musical / writer      -1   m
# 25                     medicine / health      -1   m
# 26             clerical / administrative      -1   m
# 27                                 other      -1   m
# 28                                  None      -1   m
# 29                                 other      -1   m
# ...                                  ...     ...  ..
# 59913                               None      -1   f
# 59914                     rather not say  100000   m
# 59915                              other      -1   f
# 59916        sales / marketing / biz dev      -1   f
# 59917       science / tech / engineering      -1   f
# 59918              entertainment / media      -1   f
# 59919                            student      -1   f
# 59920                            student      -1   m
# 59921                               None      -1   f
# 59922        sales / marketing / biz dev      -1   f
# 59923                               None      -1   f
# 59924                              other   50000   f
# 59925       science / tech / engineering      -1   m
# 59926        artistic / musical / writer      -1   m
# 59927             political / government   70000   m
# 59928       science / tech / engineering      -1   m
# 59929                              other      -1   m
# 59930                               None      -1   f
# 59931                              other   80000   f
# 59932                               None      -1   f
# 59933                              other      -1   f
# 59934               education / academia      -1   m
# 59935                               None      -1   m
# 59936             executive / management      -1   m
# 59937                               None      -1   f
# 59938        sales / marketing / biz dev      -1   f
# 59939              entertainment / media      -1   m
# 59940       construction / craftsmanship  100000   m
# 59941                  medicine / health      -1   m
# 59942                  medicine / health      -1   m
#
#                                      offspring
# 0       doesn't have kids, but might want them
# 1       doesn't have kids, but might want them
# 2                                         None
# 3                            doesn't want kids
# 4                                         None
# 5       doesn't have kids, but might want them
# 6                                         None
# 7            doesn't have kids, but wants them
# 8                            doesn't have kids
# 9                                         None
# 10                                        None
# 11                                        None
# 12                           doesn't have kids
# 13                                        None
# 14           doesn't have kids, but wants them
# 15                           doesn't have kids
# 16                                        None
# 17                           doesn't have kids
# 18                                        None
# 19                           doesn't have kids
# 20                                        None
# 21      doesn't have kids, but might want them
# 22      doesn't have kids, but might want them
# 23                                        None
# 24                                        None
# 25           doesn't have kids, but wants them
# 26                                        None
# 27                                        None
# 28                                        None
# 29                                        None
# ...                                        ...
# 59913   doesn't have kids, but might want them
# 59914                                     None
# 59915                                     None
# 59916                                     None
# 59917                        doesn't have kids
# 59918                                     None
# 59919  doesn't have kids, and doesn't want any
# 59920        doesn't have kids, but wants them
# 59921                                     None
# 59922                                     None
# 59923                                     None
# 59924        doesn't have kids, but wants them
# 59925                                     None
# 59926                                     None
# 59927                                     None
# 59928                                     None
# 59929                        doesn't want kids
# 59930                                     None
# 59931                                has a kid
# 59932                                 has kids
# 59933                        doesn't have kids
# 59934                                     None
# 59935                        doesn't have kids
# 59936                        doesn't want kids
# 59937                                     None
# 59938                                 has kids
# 59939                        doesn't have kids
# 59940                        doesn't have kids
# 59941        doesn't have kids, but wants them
# 59942                                     None
#
# [59943 rows x 13 columns]

# %%
#setting index to 'id' column

df_demographic = df_demographic.set_index('id')

# %%
# checking table to make sure all looks well
df_demographic.head()
# Out:
#     age       body_type     status     smokes orientation      drugs  \
# id
# 1    22  a little extra     single  sometimes    straight      never
# 2    35         average     single         no    straight  sometimes
# 3    38            thin  available         no    straight       None
# 4    23            thin     single         no    straight       None
# 5    29        athletic     single         no    straight      never
#
#       drinks               diet                          job  income sex  \
# id
# 1   socially  strictly anything               transportation      -1   m
# 2      often       mostly other         hospitality / travel   80000   m
# 3   socially           anything                         None      -1   m
# 4   socially         vegetarian                      student   20000   m
# 5   socially               None  artistic / musical / writer      -1   m
#
#                                  offspring
# id
# 1   doesn't have kids, but might want them
# 2   doesn't have kids, but might want them
# 3                                     None
# 4                        doesn't want kids
# 5                                     None

# %% [markdown]
# ## <a name="wrangle">3. Explore the data in Python.</a>
#
# ### Exercise 3.
#
# The goals for this exploratory data analysis include:
# * Check for “weird” things in the data:
#     * missing values (empty, null, N/A, - )
#     * errors
#     * outliers
# * Identify types of data and summarize data using statistics and appropriate measures of central tendency
# * Generate appropriate data visualizations
#
# **Exploratory data analysis - Step 1.** Check for “weird” things in the data
#
# In this section, we want to discover the number of observations (respondents), identify missing data, investigate whether their are errors in the data and understand if variables need to be recoded.

# %%
# Import all the neccessary packages and functions. 
# You're going to need Pandas, Numpy, matplotlib and Seaborn
# Include the matplotlib statement to set display settings as inline

#importing all the necessary libraries

### ENTER YOUR CODE BELOW HERE
import pandas as pd
import matplotlib
import seaborn as Sea
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# List the columns to be sure everything loaded into the 
# dataFrame correctly.


### ENTER YOUR CODE BELOW HERE

df_demographic.columns
# Out:
# Index([u'age', u'body_type', u'status', u'smokes', u'orientation', u'drugs',
#        u'drinks', u'diet', u'job', u'income', u'sex', u'offspring'],
#       dtype='object')

# %% [markdown]
# It is a good idea to check and make sure you imported the data correctly. One way to do this is to look at the head of each file. You can check to make sure that the data goes all the way to the last column, verify you have the correct number of columns and make sure you did not accidently import the same file twice.

# %%
# Look the data to reveal the first few lines of the dataframe.

### ENTER YOUR CODE BELOW HERE
df_demographic.head()
# Out:
#     age       body_type     status     smokes orientation      drugs  \
# id
# 1    22  a little extra     single  sometimes    straight      never
# 2    35         average     single         no    straight  sometimes
# 3    38            thin  available         no    straight       None
# 4    23            thin     single         no    straight       None
# 5    29        athletic     single         no    straight      never
#
#       drinks               diet                          job  income sex  \
# id
# 1   socially  strictly anything               transportation      -1   m
# 2      often       mostly other         hospitality / travel   80000   m
# 3   socially           anything                         None      -1   m
# 4   socially         vegetarian                      student   20000   m
# 5   socially               None  artistic / musical / writer      -1   m
#
#                                  offspring
# id
# 1   doesn't have kids, but might want them
# 2   doesn't have kids, but might want them
# 3                                     None
# 4                        doesn't want kids
# 5                                     None

# %%
# Look at the data types for all the columns in the DataFrame.

### ENTER YOUR CODE BELOW HERE
df_demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59943 entries, 1 to 60552
# Data columns (total 12 columns):
# age            59943 non-null int64
# body_type      54647 non-null object
# status         59943 non-null object
# smokes         54431 non-null object
# orientation    59943 non-null object
# drugs          45864 non-null object
# drinks         56958 non-null object
# diet           35549 non-null object
# job            51745 non-null object
# income         59943 non-null int64
# sex            59943 non-null object
# offspring      24383 non-null object
# dtypes: int64(2), object(10)
# memory usage: 5.9+ MB

# %% [markdown]
# Are the data types correct? Think about what stats and visualizations you may want to generate. Are the data types compatible with the visualizations you want to generate?
#
# Pay special attention to those that are assigned the 'object' dtype. This is often the default data type when Pandas cannot easily assign another value.

# %%
# Reassign any variable types if needed. 

### EXAMPLE CODE
df_demographic['sex'] = df_demographic['sex'].astype('category')
### END EXAMPLE CODE

### ENTER YOUR CODE BELOW HERE
## in this block of code I am converting the data types of all columns that are objects into categorical data
## categorical data i
df_demographic['body_type'] = df_demographic['body_type'].astype('category')
df_demographic['status'] = df_demographic['status'].astype('category')
df_demographic['smokes'] = df_demographic['smokes'].astype('category')
df_demographic['orientation'] = df_demographic['orientation'].astype('category')
df_demographic['drugs'] = df_demographic['drugs'].astype('category')
df_demographic['drinks'] = df_demographic['drinks'].astype('category')
df_demographic['diet'] = df_demographic['diet'].astype('category')
df_demographic['job'] = df_demographic['job'].astype('category')
df_demographic['sex'] = df_demographic['sex'].astype('category')
df_demographic['offspring'] = df_demographic['offspring'].astype('category')

df_demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59943 entries, 1 to 60552
# Data columns (total 12 columns):
# age            59943 non-null int64
# body_type      54647 non-null category
# status         59943 non-null category
# smokes         54431 non-null category
# orientation    59943 non-null category
# drugs          45864 non-null category
# drinks         56958 non-null category
# diet           35549 non-null category
# job            51745 non-null category
# income         59943 non-null int64
# sex            59943 non-null category
# offspring      24383 non-null category
# dtypes: category(10), int64(2)
# memory usage: 1.9 MB

# %% [markdown]
# Are there any missing values (null/NaN) in your data?
#
# I am mainly focusing on income, age and sex ans these do not have any null values.
#
# Should we drop the null values from our original DataFrame?
#
# Hint: If you drop the values from the DataFrame itself, then you lose the whole row that contains that value. Create a separate subset dataframe, then drop the null values from the child dataframe. This will be helpful to generate  plots without the 'nan' values getting in the way.

# %%
df_demographic.isnull().sum()
# Out:
# age                0
# body_type       5296
# status             0
# smokes          5512
# orientation        0
# drugs          14079
# drinks          2985
# diet           24394
# job             8198
# income             0
# sex                0
# offspring      35560
# dtype: int64

# %%
# Create separate series or a subset DataFrame for specific columns, then
# drop the null values.

### EXAMPLE CODE
subset = df_demographic[['sex', 'age' ]].dropna()
### END EXAMPLE CODE

### ENTER YOUR CODE BELOW HERE
# I did not have to remove any nulls at this time
# I am creating a subset consisting only of age, sex and income

sub1 = df_demographic[['sex', 'age', 'income', 'status']].dropna

# %%
# Create a subset DataFrame which excludes any extreme outliers
# for the columns you are interested in. 

### ENTER YOUR CODE BELOW HERE

sub2 = df_demographic[['sex', 'age', 'income','status']]

# %%
sub2 = sub2[sub2['income'] != -1]

# %%
sub2 = sub2[sub2['income'] < 300000]

# %% [markdown]
# Are there any outliers?
#
# Yes, there are values like -1 and 1000000 for income. For age there are valuees like 110.
#
# Use .describe() to assess missing values and look at the distribution/range of each variable. If you see a value like 9999 or something that looks out of place, it is a clue that your data may require some further cleaning.
#
# Do these numbers make sense?
#
# **Exploratory data analysis - Step 2.** Identify type of data and summarize using statistics and appropriate measures of central tendency.

# %%
# Look at the descriptive statistics to assess for outliers.

### ENTER YOUR CODE BELOW HERE
#Taking a look at my data to make sure the outliers have been removed
sub2.describe()
# Out:
#                 age         income
# count  10934.000000   10934.000000
# mean      32.631882   59989.025059
# std        9.825047   42517.716467
# min       18.000000   20000.000000
# 25%       26.000000   20000.000000
# 50%       30.000000   50000.000000
# 75%       38.000000   80000.000000
# max       69.000000  250000.000000

# %%
#checking for any remaining outliers
	
sub2.describe()
# Out:
#                 age         income
# count  10934.000000   10934.000000
# mean      32.631882   59989.025059
# std        9.825047   42517.716467
# min       18.000000   20000.000000
# 25%       26.000000   20000.000000
# 50%       30.000000   50000.000000
# 75%       38.000000   80000.000000
# max       69.000000  250000.000000

# %%
# Get the summary statistics for profiles
# (outliers, null values excluded).

### ENTER YOUR CODE BELOW HERE

sub2.head(15)
# Out:
#     sex  age  income          status
# id
# 2     m   35   80000          single
# 4     m   23   20000          single
# 12    m   28   40000  seeing someone
# 14    f   30   30000          single
# 15    f   29   50000          single
# 44    m   40   60000          single
# 67    m   22   20000          single
# 73    m   35  150000          single
# 74    f   31   50000          single
# 80    m   21   20000          single
# 83    m   34  100000          single
# 93    f   29   50000       available
# 95    m   29   40000          single
# 96    m   25   80000          single
# 104   m   39  100000          single

# %%
sub2.shape
# Out:
# (10934, 4)

# %% [markdown]
# **Exploratory data analysis - Step 3** Generate appropriate data visualizations

# %% [markdown]
# Descriptive statistics provide convenient values that summarize the tendencies and general shape of the data. However, a picture is worth a thousand words. Plot the distribution of a interval/ratio (numeric) data or countplot for nominal/ordinal (categorical) data.

# %%
# Plot distributions for interval/ratio (numeric) data.

### ENTER YOUR CODE BELOW HERE
Sea.distplot(sub2["income"])

# %%
Sea.distplot(sub2["age"])

# %%
# Plot countplots for nominal/ordinal (categorical) data.

### ENTER YOUR CODE BELOW HERE
Sea.countplot(sub2["sex"])

# %%
# Insert some bivariate visualizations to make some comparisons
# to test your hypotheses. 

### ENTER YOUR CODE BELOW HERE
# taking a look at bot income and age in one bivariate visualization
#Bivariate visualization #1
g = Sea.jointplot(x="income", y="age", data = sub2)

# %%
#Bivariate visualization#2
g = Sea.jointplot("income", "age", data=sub2, kind="reg")

# %%
#Bivariate visualization#3
Sea.jointplot("income", "age", data=sub2, kind="hex")

# %%
#Bivariate visualization#4
Sea.jointplot("income", "age", data=sub2,
                   kind="kde", space=0, color="g")

# %%
#Bivariate visualization with categorical data #1
Sea.stripplot(x="sex", y="income", data=sub2);

# %%
#Bivariate visualization with categorical data #2
Sea.barplot(x="sex", y="income", data=sub2);

# %%
#Bivariate visualization with categorical data #3
Sea.barplot(x="sex", y="income",hue='age', data=sub2);

# %%
#Bivariate visualization with categorical data #4
Sea.barplot(x="age", y="income",hue='sex', data=sub2);

# %%
#Bivariate visualization with categorical data #5
Sea.boxplot(x="income", y="age", hue="sex", data=sub2);

# %%
#Bivariate visualization with categorical data #6
Sea.boxplot(x="income", y="status", hue="sex", data=sub2);

# %%
#Bivariate visualization with categorical data #7
Sea.barplot(x="sex", y="income",hue='status', data=sub2);

# %%
#Bivariate visualization with categorical data #8
Sea.barplot(x="sex", y="age",hue='status', data=sub2);

# %%
#Bivariate visualization with categorical data #9
Sea.stripplot(x="status", y="income", data=sub2);

# %%
#Bivariate visualization with categorical data #10
Sea.stripplot(x="status", y="age",hue='sex', data=sub2);

# %%
#Bivariate countplot #1 of income, status and sex
Sea.factorplot(x="income", hue="status", col="sex",
...                    data=sub2, kind="count",
...                    size=10, aspect=.7);

# %%
Sea.countplot(x="sex", data=sub2)

# %% [markdown]
# ## <a name="test">4. Test your hypotheses in Python.</a>
#
# ### Exercise 4
#
# Now that we have visualized and summarized the data, we want to think about how these data can inform the Marketing Department's future decisions. Ad buys are often done based on demographic segments, e.g. males 18-24, females 18-24, males 25-34, females 25-34, males 35-44, females 35-44, and everyone over age 45.
#
# ** QUESTION 1. What market segments might the marketing department be interested in? What are our sample sizes for each of these markets? **
#
# *The marketing segments that the marketing sept. will most likly be interested are males in their 30's. The sample sizes for these categories are 59943.
#
# ** QUESTION 2. What do our measures of central tendency (i.e., descriptive statistics) tell us about each groups? Hint: what are the most common traits associated with each group? **
#
# *They are often below the income level of 60k-100k and also most often single. Income does increase with age however and there are more older than 40 men on okcupid than women. *
#
# ** QUESTION 3. What is the buy power of each group? Hint: look at income. **
#
# *Single men who are 30+ years old have the highest buying power becuase their incomes are often higher than women and there are also more men than women*
#
# ** QUESTION 4. A company in San Francisco sells children's clothes. Would OKCupid be a good place to advertise? **
#
# *No!, Single men who are 30+ are the target demographic.*
#
# ** QUESTION 5. Use a t-test to determine whether there is a difference in mean incomes between men and women of the same age group (25 - 34). What is the p-value? What are the means and standard deviations of the incomes you compared? What can you conclude from these results? **
#
# *From these results we can conclude that males have higher incomes on average, however also have a higher standard deviation. It would seem that we can conclude men are the preferred demographic as they are more likely to have money to spend.

# %%
# Run a t-test.
#created two subsets one of males and one of females with age range 25-34
age_subset = sub2[sub2['age'] >=25]
age_subset = age_subset[age_subset['age'] <= 34]

male_subset= age_subset[age_subset['sex']== 'm']
female_subset = age_subset[age_subset['sex'] == 'f']

# %%
#Checking the mean of the male subset within age range 25-34 
male_subset.describe()
# Out:
#                age         income
# count  3905.000000    3905.000000
# mean     28.947247   63339.308579
# std       2.717163   42369.784292
# min      25.000000   20000.000000
# 25%      27.000000   30000.000000
# 50%      29.000000   50000.000000
# 75%      31.000000   80000.000000
# max      34.000000  250000.000000

# %%
#Checking the mean of the female subset within age range 25-34 
female_subset.describe()
# Out:
#                age         income
# count  1317.000000    1317.000000
# mean     28.980258   45018.982536
# std       2.857493   28438.657461
# min      25.000000   20000.000000
# 25%      27.000000   20000.000000
# 50%      29.000000   40000.000000
# 75%      31.000000   60000.000000
# max      34.000000  250000.000000

# %%
#isolating the mean
male_subset.mean()
# Out:
# age          28.947247
# income    63339.308579
# dtype: float64

# %%
#isolating the std
male_subset.std()
# Out:
# age           2.717163
# income    42369.784292
# dtype: float64

# %%
#isolating the mean
female_subset.mean()
# Out:
# age          28.980258
# income    45018.982536
# dtype: float64

# %%
#isolating the std
female_subset.std()
# Out:
# age           2.857493
# income    28438.657461
# dtype: float64

# %% [markdown]
# ** QUESTION 6 (Stretch/Optional): User engagement drives ad revenue. To make the biggest impact in your analysis, examine this  Which group has the highest engagement? Hint: use the 'datetime' data type. **
#
# *ANSWER HERE*

# %%
# Optional - insert user engagement code here.

# %% [markdown]
# ## <a name="communicate">5. Communicate your findings.</a>
#
# <b>Exercise 5.</b>
#
# *Who is your intended audience?* Your report is going to Rachel, but it sounds like this is going to end up in the Chief Marketing Officer's hands. Assume that the CMO does not have a strong understanding of statistics, so you will need to share succinct explanations and translate those results into business insights that both the lay CMO and your data-savvy boss will understand.
#
# *What is the executive summary of your findings?* You should begin your report with 2-4 sentences that include the most actionable insights and your recommendations. The CMO is probably in back-to-back with meetings and doesn't have time to dig into the data or polish your presentation.
#
# *What are the key visualizations that summarize your results?* Descriptive statistics are very revealing to data-savvy analysts such as yourself. Most importantly, your visualizations should be polished and appropriately labeled.
#
# *What data support your findings?* Include one key point per slide. The title of each slide should be a statement, which clearly states the takeaway point of the slide. The visualization should stand alone to support the key takeaway. Add a few bullet points (no more than three) if needed to clarify.
#
# Hint: how can you make the demographic data interesting and useful for your higher-ups? Look back at your Design Thinking and marketing seminars from T1. Looking at the medians of your data to tell you something about your median user and build <a href="https://blog.bufferapp.com/marketing-personas-beginners-guide">personas</a>.
